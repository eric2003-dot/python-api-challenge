# %%
 # Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import gmaps
import gmaps.datasets
import os

# Import API key
from api_key import g_key

# %%
# Store Weather Py 

weather_df=pd.read_csv("Weather_Py.csv")
weather_df
weather_df.head()
# Out:
#    Unnamed: 0          City  Cloudiness Country        Date  Humidity  \
# 0           0  Batemans Bay          89      AU  1610412519        40
# 1           1   Yellowknife          20      CA  1610412519        92
# 2           2      Khatanga         100      RU  1610412519        89
# 3           3         Yumbe           0      UG  1610412519        33
# 4           4       Ushuaia          75      AR  1610412519        76
#
#        Lat       Lng  Max Temp  Wind Speed
# 0 -35.7167  150.1833     84.99        4.00
# 1  62.4560 -114.3525      8.60        9.22
# 2  71.9667  102.5000    -18.33        3.44
# 3   3.4651   31.2469     71.02        4.16
# 4 -54.8000  -68.3000     46.40       13.80

# %%
#humidity heatmap

locations = weather_df[["Lat", "Lng"]]
weights = weather_df["Humidity"]
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create Ideal Weather Data Frame
ideal_weather=weather_df[(weather_df["Max Temp"]<80)&(weather_df["Max Temp"]>70)&(weather_df["Wind Speed"]<10)&(weather_df["Cloudiness"]==0)]
ideal_weather

hotel_df = ideal_weather
hotel_df
# Out:
#      Unnamed: 0                 City  Cloudiness Country        Date  \
# 3             3                Yumbe           0      UG  1610412519
# 19           19                 Dori           0      BF  1610412522
# 23           23              Mataura           0      NZ  1610412522
# 101         101            Tuatapere           0      NZ  1610412534
# 121         121            Boundiali           0      CI  1610412538
# 161         161            Deloraine           0      AU  1610412544
# 192         192                Morón           0      AR  1610412511
# 309         309              Lafiagi           0      NG  1610412571
# 348         348               Juruti           0      BR  1610412577
# 377         377                  Gao           0      ML  1610412581
# 402         402              Yenagoa           0      NG  1610412586
# 431         431      Lázaro Cárdenas           0      MX  1610412534
# 463         463              Te Anau           0      NZ  1610412595
# 465         465              Angoche           0      MZ  1610412596
# 477         477               Maceió           0      BR  1610412598
# 501         501               Kpandu           0      GH  1610412603
# 510         510  São Raimundo Nonato           0      BR  1610412606
#
#      Humidity      Lat       Lng  Max Temp  Wind Speed
# 3          33   3.4651   31.2469     71.02        4.16
# 19         20  14.0354   -0.0345     72.23        7.96
# 23         34 -46.1927  168.8643     74.89        1.77
# 101        41 -46.1333  167.6833     71.80        3.51
# 121        35   9.5217   -6.4869     76.91        2.77
# 161        48 -41.5333  146.6667     75.99        1.99
# 192        83 -34.6534  -58.6198     73.40        6.91
# 309        23   8.8667    5.4167     76.35        0.83
# 348        73  -2.1522  -56.0922     78.06        1.70
# 377        19  16.6362    1.6370     72.82        8.68
# 402        90   4.9247    6.2642     75.90        4.36
# 431        72  17.9583 -102.2000     74.91        2.82
# 463        47 -45.4167  167.7167     71.65        3.58
# 465        83 -16.2325   39.9086     78.91        7.78
# 477        83  -9.6658  -35.7353     77.00        5.75
# 501        76   6.9954    0.2931     79.11        9.10
# 510        80  -9.0153  -42.6994     73.26        3.36

# %%
hotel_df['Hotel Name'] = ""
hotel_df
# Out:
# <ipython-input-50-cb2d5672db59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = ""
#      Unnamed: 0                 City  Cloudiness Country        Date  \
# 3             3                Yumbe           0      UG  1610412519
# 19           19                 Dori           0      BF  1610412522
# 23           23              Mataura           0      NZ  1610412522
# 101         101            Tuatapere           0      NZ  1610412534
# 121         121            Boundiali           0      CI  1610412538
# 161         161            Deloraine           0      AU  1610412544
# 192         192                Morón           0      AR  1610412511
# 309         309              Lafiagi           0      NG  1610412571
# 348         348               Juruti           0      BR  1610412577
# 377         377                  Gao           0      ML  1610412581
# 402         402              Yenagoa           0      NG  1610412586
# 431         431      Lázaro Cárdenas           0      MX  1610412534
# 463         463              Te Anau           0      NZ  1610412595
# 465         465              Angoche           0      MZ  1610412596
# 477         477               Maceió           0      BR  1610412598
# 501         501               Kpandu           0      GH  1610412603
# 510         510  São Raimundo Nonato           0      BR  1610412606
#
#      Humidity      Lat       Lng  Max Temp  Wind Speed Hotel Name
# 3          33   3.4651   31.2469     71.02        4.16
# 19         20  14.0354   -0.0345     72.23        7.96
# 23         34 -46.1927  168.8643     74.89        1.77
# 101        41 -46.1333  167.6833     71.80        3.51
# 121        35   9.5217   -6.4869     76.91        2.77
# 161        48 -41.5333  146.6667     75.99        1.99
# 192        83 -34.6534  -58.6198     73.40        6.91
# 309        23   8.8667    5.4167     76.35        0.83
# 348        73  -2.1522  -56.0922     78.06        1.70
# 377        19  16.6362    1.6370     72.82        8.68
# 402        90   4.9247    6.2642     75.90        4.36
# 431        72  17.9583 -102.2000     74.91        2.82
# 463        47 -45.4167  167.7167     71.65        3.58
# 465        83 -16.2325   39.9086     78.91        7.78
# 477        83  -9.6658  -35.7353     77.00        5.75
# 501        76   6.9954    0.2931     79.11        9.10
# 510        80  -9.0153  -42.6994     73.26        3.36

# %%
for index, row in hotel_df.iterrows():
    try:
        
        base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

        params = {
        "keyword": "hotel",
        "radius": 5000,
        "key": g_key,
        }


        lat = row['Lat']
        lng = row['Lng']

        params['location'] = f"{lat}, {lng}"

        hotel_data = requests.get(base_url, params=params).json()
        
        hotel_df.loc[index, "Hotel Name"] = hotel_data["results"][0]["name"]
        
    except IndexError:
        
        hotel_df.loc[index, "Hotel Name"] = "NaN"
        
hotel_df
# Out:
# /Users/bucky/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#      Unnamed: 0                 City  Cloudiness Country        Date  \
# 3             3                Yumbe           0      UG  1610412519
# 19           19                 Dori           0      BF  1610412522
# 23           23              Mataura           0      NZ  1610412522
# 101         101            Tuatapere           0      NZ  1610412534
# 121         121            Boundiali           0      CI  1610412538
# 161         161            Deloraine           0      AU  1610412544
# 192         192                Morón           0      AR  1610412511
# 309         309              Lafiagi           0      NG  1610412571
# 348         348               Juruti           0      BR  1610412577
# 377         377                  Gao           0      ML  1610412581
# 402         402              Yenagoa           0      NG  1610412586
# 431         431      Lázaro Cárdenas           0      MX  1610412534
# 463         463              Te Anau           0      NZ  1610412595
# 465         465              Angoche           0      MZ  1610412596
# 477         477               Maceió           0      BR  1610412598
# 501         501               Kpandu           0      GH  1610412603
# 510         510  São Raimundo Nonato           0      BR  1610412606
#
#      Humidity      Lat       Lng  Max Temp  Wind Speed  \
# 3          33   3.4651   31.2469     71.02        4.16
# 19         20  14.0354   -0.0345     72.23        7.96
# 23         34 -46.1927  168.8643     74.89        1.77
# 101        41 -46.1333  167.6833     71.80        3.51
# 121        35   9.5217   -6.4869     76.91        2.77
# 161        48 -41.5333  146.6667     75.99        1.99
# 192        83 -34.6534  -58.6198     73.40        6.91
# 309        23   8.8667    5.4167     76.35        0.83
# 348        73  -2.1522  -56.0922     78.06        1.70
# 377        19  16.6362    1.6370     72.82        8.68
# 402        90   4.9247    6.2642     75.90        4.36
# 431        72  17.9583 -102.2000     74.91        2.82
# 463        47 -45.4167  167.7167     71.65        3.58
# 465        83 -16.2325   39.9086     78.91        7.78
# 477        83  -9.6658  -35.7353     77.00        5.75
# 501        76   6.9954    0.2931     79.11        9.10
# 510        80  -9.0153  -42.6994     73.26        3.36
#
#                   Hotel Name
# 3              Terrain Hotel
# 19              Dintal Hotel
# 23               Falls Hotel
# 101            Tui Base Camp
# 121             IMAN S HOTEL
# 161   Empire Hotel Deloraine
# 192            Hotel Cabildo
# 309           One to Z Hotel
# 348            Hotel Barroso
# 377                      NaN
# 402          De Brass Suites
# 431      Hotel de Casablanca
# 463  Lakefront Lodge Te Anau
# 465       Guest House HESADA
# 477   Jatiúca Hotel & Resort
# 501              Hotor Hotel
# 510               Real Hotel

# %%
# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""


# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
